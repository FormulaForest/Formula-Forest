# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
F10 = pd.read_csv("BF10mps.csv")
F20 = pd.read_csv("BF20mps.csv")
M10 = pd.read_csv("BM10mps.csv")
M20 = pd.read_csv("BM20mps.csv")

# %%
F10[["Time (s)", "TOTAL_FORCE_Y"]]
# Out:
#       Time (s)  TOTAL_FORCE_Y
# 0            1       5.813375
# 1            2       3.315750
# 2            3       2.880567
# 3            4       2.690242
# 4            5       1.740078
# ...        ...            ...
# 1995      1996       0.051980
# 1996      1997       0.053405
# 1997      1998       0.049932
# 1998      1999       0.050013
# 1999      2000       0.050164
#
# [2000 rows x 2 columns]

# %%
F10[["Time (s)", "TOTAL_FORCE_Y", "TOTAL_FORCE_Z"]][F10["Time (s)"] > 1400].plot(x="Time (s)", title="B10mps")
# Out:
# <Axes: title={'center': 'B10mps'}, xlabel='Time (s)'>

# %%
F10[["Time (s)", "TOTAL_FORCE_Y", "TOTAL_FORCE_Z"]][F10["Time (s)"] > 1400].mean()
# Out:
# Time (s)         1700.500000
# TOTAL_FORCE_Y       0.050876
# TOTAL_FORCE_Z       0.011476
# dtype: float64

# %%
F20[["Time (s)", "TOTAL_FORCE_Y", "TOTAL_FORCE_Z"]][F20["Time (s)"] > 1400].mean()
# Out:
# Time (s)         1700.500000
# TOTAL_FORCE_Y       0.182705
# TOTAL_FORCE_Z       0.043031
# dtype: float64

# %% [markdown]
# # Test LSF

# %%
v = np.linspace(0, 25, 1000)
fy = v**3 * -5.199750e-06 - v**2 * -5.607575e-04

# %%
plt.plot(v, fy, label="$F_x$")
plt.scatter([10, 20], [0.050876, 0.182705], color='red', label='Points')  # Add two points
plt.legend()
